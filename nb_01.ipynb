# %% [markdown]
# Download the dataset from roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="UjVLCDuAMxom6CBhWdDX")
project = rf.workspace("defect-detection-guglj").project("defects_dataset_new-utjup")
version = project.version(2)
dataset = version.download("darknet")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
from ultralytics.models.yolo.detect import DetectionPredictor, DetectionTrainer, DetectionValidator

# %% [markdown]
# Training yolo26-n

# %%
model = YOLO("yolo26n.pt")


results = model.train(data = "def_det.yaml",
                      epochs = 400,
                      patience = 25,
                      batch = 64,
                      imgsz = 640,
                      save = True,
                      workers = 4,
                      project = "defect_detection",
                      optimizer = "MuSGD",
                      device = 0,
                      cos_lr = True,
                      lr0 = 0.003,
                      lrf = 0.01,)
# Out:
# Ultralytics 8.4.19 🚀 Python-3.13.7 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5060 Ti, 15845MiB)
# ...

# %%
model = YOLO("runs/detect/defect_detection/train5/weights/last.pt")


results = model.train(data = "def_det.yaml",
                      epochs = 400,
                      patience = 25,
                      batch = 64,
                      imgsz = 640,
                      save = True,
                      workers = 4,
                      project = "defect_detection",
                      optimizer = "MuSGD",
                      device = 0,
                      cos_lr = True,
                      resume = True,
                      lr0 = 0.003,
                      lrf = 0.01,
                      #below parameters can be used for applying augmentation in image data
                      hsv_h = 0.015,  #Adjusts the hue of the image by a fraction of the color wheel, introducing color variability.
                      hsv_s = 0.7,   #Alters the saturation of the image by a fraction, affecting the intensity of colors.
                      hsv_v = 0.4,    #Modifies the value (brightness) of the image by a fraction,
                      degrees = 3.0,   #Rotates the image randomly within the specified degree range
                      translate = 0.1,   #Translates the image horizontally and vertically by a fraction of the image size
                      scale = 0.5,    #Scales the image by a gain factor
                      shear = 1.0,    #Shears the image by a specified degree, mimicking the effect of objects being viewed from different angles.
                      fliplr = 0.5,   #Flips the image left to right with the specified probability
                      mosaic = 1.0,    #Combines four training images into one
                      mixup = 0.15,    #Blends two images and their labels, creating a composite image
                      )
# Out:
# Ultralytics 8.4.19 🚀 Python-3.13.7 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5060 Ti, 15845MiB)
# ...

# %% [markdown]
# Training yolo26-s

# %%
model = YOLO("yolo26s.pt")


results = model.train(data = "def_det.yaml",
                      epochs = 400,
                      patience = 25,
                      batch = 64,
                      imgsz = 640,
                      save = True,
                      workers = 4,
                      project = "defect_detection",
                      optimizer = "MuSGD",
                      device = 0,
                      cos_lr = True,
                      lr0 = 0.003,
                      lrf = 0.01,)
# Out:
# ...
# Ultralytics 8.4.19 🚀 Python-3.13.7 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5060 Ti, 15845MiB)
# ...
