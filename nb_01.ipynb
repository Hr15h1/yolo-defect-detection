# %% [markdown]
# Download the dataset from roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="UjVLCDuAMxom6CBhWdDX")
project = rf.workspace("defect-detection-guglj").project("defects_dataset_new-utjup")
version = project.version(2)
dataset = version.download("darknet")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to defects_dataset_new-2 in darknet:: 100%|██████████| 28300/28300 [00:01<00:00, 14502.26it/s]

# %%
from ultralytics import YOLO
from ultralytics.models.yolo.detect import DetectionPredictor, DetectionTrainer, DetectionValidator

# %% [markdown]
# Configure trainer with appropriate parameters

# %%
args = dict(
    model="yolo26n.pt",
    data = "def_det.yaml",
    epochs = 400,
    patience = 50,
    batch = 16,
    imgsz = 640,
    save = True,
    workers = 4,
    project = "defect_detection",
    optimizer = "MuSGD",
    device = 0,
    cos_lr = True,
    resume = True,
    lr0 = 0.003,
    lrf = 0.01,
)

trainer = DetectionTrainer(overrides=args)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.13.7 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# ...

# %% [markdown]
# Run the below cell to start training the model

# %%
trainer.train()
# Out:
# Overriding model.yaml nc=80 with nc=13
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...
